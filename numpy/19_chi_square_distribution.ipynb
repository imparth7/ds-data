# %% [markdown]
# # Chi Square Distribution
#
# It is basically used as a basis to verify the hypothesis.
#
# param - df(degree of freedom), size

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Sample for Chi Square Distribution with df 2 with size 2*3

# %%
x = random.chisquare(df=2, size=(2, 3))
x
# Out:
# array([[0.62770192, 2.44614212, 0.98823822],
#        [0.01906961, 5.93675892, 2.73206211]])

# %% [markdown]
# Visualization of Chi Square Distribution

# %%
sns.distplot(random.chisquare(df=1, size=1000), hist=False)
plt.show()
# Out:
# /tmp/ipykernel_19275/3315153496.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.chisquare(df=1, size=1000), hist=False)
