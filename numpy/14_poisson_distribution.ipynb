# %% [markdown]
# # Poisson Distribution
#
# It estimates How many time an event can happen.
#
# param - lam(number of occurance or rate), size

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Generate a random 1*10 dist for the occurance 2

# %%
x = random.poisson(lam=2, size=10)
x
# Out:
# array([4, 2, 1, 2, 0, 4, 2, 2, 1, 4])

# %% [markdown]
# Visualization of poisson dist

# %%
sns.distplot(random.poisson(lam=2, size=10), kde=False)
plt.show()
# Out:
# /tmp/ipykernel_3943/4196699098.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=10), kde=False)

# %% [markdown]
# Presenting both the plots in same figure normal and poisson dist.

# %%
sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label="Normal")
sns.distplot(random.poisson(lam=50, size=1000), hist=False, label="Poisson")
plt.show()
# Out:
# /tmp/ipykernel_3943/2300383784.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label="Normal")
# /tmp/ipykernel_3943/2300383784.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=50, size=1000), hist=False, label="Poisson")

# %% [markdown]
# ```math
# n*p == lam
# ```
