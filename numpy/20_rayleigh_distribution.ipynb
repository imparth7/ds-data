# %% [markdown]
# # Rayleigh Distribution
#
# It is used in signal processing.
#
# param - scale(standard deviation, how flat the distribution is ... default 1.0), size

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Sample for Rl with scale of 2.0 with size of 2*3

# %%
x = random.rayleigh(scale=2, size=(2, 3))
x
# Out:
# array([[2.25981161, 2.44183505, 1.23907625],
#        [2.71218621, 2.95464639, 0.33955625]])

# %% [markdown]
# Visualization of Rayleigh Distribution

# %%
sns.distplot(random.rayleigh(size=1000), hist=False)
plt.show()
# Out:
# /tmp/ipykernel_21182/2338677170.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.rayleigh(size=1000), hist=False)
