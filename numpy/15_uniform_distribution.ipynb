# %% [markdown]
# # Uniform Distribution
#
# It is only made for probability(p).
#
# param - a(lower bound - 0.0), b(upper boubnd - 1.0), size

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = random.uniform(size=(2, 3))
x
# Out:
# array([[0.12407379, 0.47302651, 0.44793065],
#        [0.75324395, 0.34842368, 0.10556436]])

# %% [markdown]
# Visualization of uniform dist

# %%
sns.distplot(random.uniform(size=1000), hist=False)
plt.show()
# Out:
# /tmp/ipykernel_7898/1494691810.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=1000), hist=False)
